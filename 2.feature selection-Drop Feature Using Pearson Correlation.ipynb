# %% [markdown]
# # 2.Feature selection-with correlation

# %%
# importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading the dataset
data = load_boston()
df = pd.DataFrame(data.data, columns = data.feature_names )
df['MEDV'] = data.target

# %%
data.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [raw]
# ##if the indpendent feature are highly correlated with dependent feature then it play important role.
# #if there are 3 or 4 independent feature are highly correlated than 90% then we can consist that except one feature we can remove other features.

# %%
X = df.drop("MEDV",axis=1)   #feature Matrix
y = df["MEDV"]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
X.shape
# Out:
# (506, 13)

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
y.shape
# Out:
# (506,)

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)
    
X_train.shape, X_test.shape
# Out:
# ((354, 13), (152, 13))

# %%
X_train.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.196172  0.382073 -0.049364  0.416560 -0.188280  0.329927
# ZN      -0.196172  1.000000 -0.529392 -0.063863 -0.523572  0.319260 -0.583885
# INDUS    0.382073 -0.529392  1.000000  0.044224  0.750218 -0.392969  0.629257
# CHAS    -0.049364 -0.063863  0.044224  1.000000  0.043748  0.088125  0.067269
# NOX      0.416560 -0.523572  0.750218  0.043748  1.000000 -0.279202  0.740052
# RM      -0.188280  0.319260 -0.392969  0.088125 -0.279202  1.000000 -0.235839
# AGE      0.329927 -0.583885  0.629257  0.067269  0.740052 -0.235839  1.000000
# DIS     -0.355840  0.658331 -0.686848 -0.085492 -0.765753  0.183857 -0.761543
# RAD      0.603880 -0.314833  0.578459  0.022338  0.627188 -0.179242  0.440578
# TAX      0.560570 -0.327834  0.719038 -0.017156  0.683445 -0.275242  0.502429
# PTRATIO  0.264780 -0.392838  0.388353 -0.072683  0.179046 -0.385526  0.239729
# ...

# %%
import seaborn as sns
#Using pearson correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first features that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  #set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:  # we are interested in absolute(abs = to get -ve values also) coeff  value 
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'AGE', 'DIS', 'NOX', 'TAX'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#          CRIM   ZN  INDUS  CHAS     RM   RAD  PTRATIO       B  LSTAT
# 329   0.06724  0.0   3.24   0.0  6.333   4.0     16.9  375.21   7.34
# 371   9.23230  0.0  18.10   0.0  6.216  24.0     20.2  366.15   9.53
# 219   0.11425  0.0  13.89   1.0  6.373   5.0     16.4  393.74  10.50
# 403  24.80170  0.0  18.10   0.0  5.349  24.0     20.2  396.90  19.77
# 78    0.05646  0.0  12.83   0.0  6.232   5.0     18.7  386.40  12.34
# ..        ...  ...    ...   ...    ...   ...      ...     ...    ...
# 4     0.06905  0.0   2.18   0.0  7.147   3.0     18.7  396.90   5.33
# 428   7.36711  0.0  18.10   0.0  6.193  24.0     20.2   96.73  21.52
# 385  16.81180  0.0  18.10   0.0  5.277  24.0     20.2  396.90  30.81
# 308   0.49298  0.0   9.90   0.0  6.635   4.0     18.4  396.90   4.54
# 5     0.02985  0.0   2.18   0.0  6.430   3.0     18.7  394.12   5.21
#
# [152 rows x 9 columns]

# %% [markdown]
# # lets try with Big dataset

# %%
df=pd.read_csv('santander.csv')
X=df.drop(labels=['TARGET'],axis = 1)
y=df['TARGET']
#Seprate dataset into train and test 
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(labels=['TARGET'],axis=1),
    df['TARGET'],
    test_size=0.3,
    random_state=0)

# %%
import seaborn as sns
# Using pearson Correlation
corrmat = X_train.corr()
fig, ax = plt.subplots()
fig.set_size_inches(11,11)
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %%
corr_features = correlation(X_train, 0.8)
len(set(corr_features))
# Out:
# 206

# %%
corr_features
# Out:
# {'delta_imp_amort_var18_1y3',
#  'delta_imp_amort_var34_1y3',
#  'delta_num_aport_var13_1y3',
#  'delta_num_aport_var17_1y3',
#  'delta_num_aport_var33_1y3',
#  'delta_num_compra_var44_1y3',
#  'delta_num_reemb_var13_1y3',
#  'delta_num_reemb_var17_1y3',
#  'delta_num_trasp_var17_in_1y3',
#  'delta_num_trasp_var17_out_1y3',
#  'delta_num_trasp_var33_in_1y3',
#  'delta_num_trasp_var33_out_1y3',
#  'delta_num_venta_var44_1y3',
#  'imp_amort_var18_ult1',
#  'imp_amort_var34_ult1',
#  'imp_op_var39_comer_ult3',
#  'imp_op_var39_efect_ult1',
#  'imp_op_var39_efect_ult3',
#  'imp_op_var39_ult1',
#  'imp_op_var40_comer_ult3',
#  'imp_op_var40_efect_ult3',
#  'imp_op_var41_comer_ult1',
#  'imp_op_var41_comer_ult3',
#  'imp_op_var41_efect_ult3',
#  'imp_op_var41_ult1',
#  'imp_trasp_var17_in_ult1',
#  'imp_trasp_var17_out_ult1',
#  'imp_trasp_var33_in_ult1',
#  'imp_trasp_var33_out_ult1',
#  'imp_venta_var44_ult1',
#  'ind_var10_ult1',
#  'ind_var10cte_ult1',
#  'ind_var12',
#  'ind_var13',
# ...

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#            ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 36443   72815     2     23                 0.0                     0.00
# 17577   35209     2     23                 0.0                     0.00
# 28097   56215     2     44                 0.0                     0.00
# 34967   69919     2     24                 0.0                     0.00
# 50314  100469     2     80                 0.0                     0.00
# ...       ...   ...    ...                 ...                      ...
# 49159   98197     2     40                 0.0                  1086.00
# 38812   77662     2     43                 0.0                   552.30
# 60399  120549     2     23                 0.0                     0.00
# 40783   81608     2     31                 0.0                   426.18
# 73639  147032     2     23                 0.0                     0.00
#
#        imp_op_var40_comer_ult1  imp_op_var40_efect_ult1  imp_op_var40_ult1  \
# ...
